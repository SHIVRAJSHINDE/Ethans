# %%
import pandas as pd

# %%
import pandas as pd

file_path = r"E:\1.Eathans\Ethans\Data\Airline\Airline.csv"


# Read the Excel file
df = pd.read_csv(file_path)

# Display first few rowsabs
df.head()
# Out:
#    ID      Airline Date_of_Journey    Source Destination  \
# 0   1       IndiGo      24-03-2019  Banglore   New Delhi
# 1   2    Air India      01-05-2019   Kolkata    Banglore
# 2   3  Jet Airways      09-06-2019     Delhi      Cochin
# 3   4       IndiGo      12-05-2019   Kolkata    Banglore
# 4   5       IndiGo      01-03-2019  Banglore   New Delhi
#
#                    Route Dep_Time      Arrival_Time Duration Total_Stops  \
# 0              BLR _ DEL    22:20  22-03-2026 01:10   2h 50m    non-stop
# 1  CCU _ IXR _ BBI _ BLR    05:50             13:15   7h 25m     2 stops
# 2  DEL _ LKO _ BOM _ COK    09:25  10-06-2026 04:25      19h     2 stops
# 3        CCU _ NAG _ BLR    18:05             23:30   5h 25m      1 stop
# 4        BLR _ NAG _ DEL    16:50             21:35   4h 45m      1 stop
#
#   Additional_Info    Price
# 0         No info   3897.0
# 1         No info   7662.0
# 2         No info  13882.0
# 3         No info   6218.0
# 4         No info  13302.0

# %%
df.head()
# Out:
#    ID      Airline Date_of_Journey    Source Destination  \
# 0   1       IndiGo      24-03-2019  Banglore   New Delhi
# 1   2    Air India      01-05-2019   Kolkata    Banglore
# 2   3  Jet Airways      09-06-2019     Delhi      Cochin
# 3   4       IndiGo      12-05-2019   Kolkata    Banglore
# 4   5       IndiGo      01-03-2019  Banglore   New Delhi
#
#                    Route Dep_Time      Arrival_Time Duration Total_Stops  \
# 0              BLR _ DEL    22:20  22-03-2026 01:10   2h 50m    non-stop
# 1  CCU _ IXR _ BBI _ BLR    05:50             13:15   7h 25m     2 stops
# 2  DEL _ LKO _ BOM _ COK    09:25  10-06-2026 04:25      19h     2 stops
# 3        CCU _ NAG _ BLR    18:05             23:30   5h 25m      1 stop
# 4        BLR _ NAG _ DEL    16:50             21:35   4h 45m      1 stop
#
#   Additional_Info    Price
# 0         No info   3897.0
# 1         No info   7662.0
# 2         No info  13882.0
# 3         No info   6218.0
# 4         No info  13302.0

# %%
# HOw to install
# !pip install matplotlib

# %%
# Import matplotlib
import matplotlib.pyplot as plt

# %%
# Bar Plot
# plt.bar(COL01,COL02)
plt.bar(df['Airline'],df['Price'])
plt.show()

# %%
# Apply Title

plt.bar(df['Airline'],df['Price'])
plt.xticks(rotation=45)
plt.show()

# %%
# Apply Label

plt.bar(df['Airline'],df['Price'])
plt.xticks(rotation=45)
plt.xlabel("Airline")
plt.ylabel('Price')


plt.show()

# %%
# Apply Title

plt.bar(df['Airline'],df['Price'])
plt.xticks(rotation=45)
plt.xlabel("Airline")
plt.ylabel('Price')
plt.title("Airline Vs Price")

plt.show()

# %%
# Apply Title

plt.bar(df['Airline'],df['Price'])
plt.xlabel("Airline")
plt.ylabel('Price')
plt.title("Airline Vs Price")

plt.xticks(rotation=45)
plt.show()

# %%
# Apply FontSize
f = 15

plt.bar(df['Airline'],df['Price'])
plt.xticks(rotation=45)

plt.xlabel("Airline",fontsize=f)
plt.ylabel('Price',fontsize=f)
plt.title("Airline Vs Price",fontsize=f)
plt.show()

# %%
# Playing the parameters
# matplotlib.pyplot.bar(x, height, width=0.8, bottom=None, *, align='center')
# https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.bar.html


sizeOfFont = 15
plt.bar(df['Airline'],df['Price'],width=.9,align='center')

plt.xlabel("Airline",fontsize=f)
plt.ylabel('Price',fontsize=f)
plt.title("Airline Vs Price",fontsize=f)
plt.xticks(rotation=45)
plt.show()

# %%
# change Color
import matplotlib.pyplot as plt
sizeOfFont = 15
plt.bar(df['Airline'],df['Price'],width=.5,align='center',color=['y'])

plt.xlabel("Airline",fontsize=sizeOfFont)
plt.ylabel('Price',fontsize=sizeOfFont)
plt.title("Airline Vs Price",fontsize=sizeOfFont)
plt.xticks(rotation=45)
plt.show()

# %%
# Color
#import matplotlib.pyplot as plt
#colourValue = ['y','b','g','r','y','b','g','r']
colourValue = ['y','b','g','r','y','b','g','r']

# change Color
#import matplotlib.pyplot as plt
#sizeOfFont = 15
#plt.bar(df['Airline'],df['Price'],width=.5,align='center',color=colourValue)

#plt.xlabel("Airline",fontsize=sizeOfFont)
#plt.ylabel('Price',fontsize=sizeOfFont)
#plt.title("Airline Vs Price",fontsize=sizeOfFont)
#plt.xticks(rotation=45)
#plt.legend()
#plt.show()

# %% [markdown]
# # Seaborn

# %%
# insall Seaborn
# !pip install seaborn

# %%
import seaborn as sns
ax = sns.barplot(x=df['Airline'],y=df['Price'],ci=None)
plt.xticks(rotation=45)
plt.xticks(labels=None,rotation=45,fontsize=10,ha='center')

plt.bar_label(ax.containers[0],rotation=45)
plt.ylabel("Price")
plt.xlabel("Ariline")
plt.title("Ariline Vs Price")
plt.show()
# Out:
# C:\Users\SHIVRAJ SHINDE\AppData\Local\Temp\ipykernel_8736\916129441.py:2: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   ax = sns.barplot(x=df['Airline'],y=df['Price'],ci=None)

# %%
import seaborn as sns

sns.barplot(x=df['Airline'],y=df['Price'],palette='Accent')
plt.xticks(rotation=45)
plt.title("Airline Vs Price")
plt.show()
# Out:
# C:\Users\SHIVRAJ SHINDE\AppData\Local\Temp\ipykernel_8736\2706450342.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=df['Airline'],y=df['Price'],palette='Accent')

# %%
import seaborn as sns
sns.barplot(x=df['Airline'],y=df['Price'],errorbar=None)
plt.xticks(rotation=45)
plt.show()

# %%
import seaborn as sns
sns.barplot(x=df['Airline'],y=df['Price'])
plt.xticks(rotation=45)
plt.show()

# %%
import seaborn as sns
sns.barplot(x=df['Airline'],y=df['Price'],palette='Accent',ci=None)
plt.xticks(rotation=45)
plt.show()
# Out:
# C:\Users\SHIVRAJ SHINDE\AppData\Local\Temp\ipykernel_8736\3644847344.py:2: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.barplot(x=df['Airline'],y=df['Price'],palette='Accent',ci=None)
# C:\Users\SHIVRAJ SHINDE\AppData\Local\Temp\ipykernel_8736\3644847344.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=df['Airline'],y=df['Price'],palette='Accent',ci=None)

# %%
# sort OR arrange Alphabitically

import seaborn as sns
AirlinSortedList = ['Air Asia','Air India','GoAir','IndiGo','Jet Airways','Multiple carriers','SpiceJet','Vistara']
sns.barplot(x=df['Airline'],y=df['Price'],palette='Accent',errorbar=None,hue_order=AirlinSortedList)
plt.xticks(rotation=45)
plt.show()
# Out:
# C:\Users\SHIVRAJ SHINDE\AppData\Local\Temp\ipykernel_8736\81363112.py:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=df['Airline'],y=df['Price'],palette='Accent',errorbar=None,hue_order=AirlinSortedList)

# %%
# plot graph based on Sorted Price

df01 = df.groupby('Airline')['Price'].sum()
df01
# Out:
# Airline
# Air Asia                              1787400.0
# Air India                            16834015.0
# GoAir                                 1137045.0
# IndiGo                               11648071.0
# Jet Airways                          44824690.0
# Jet Airways Business                   350152.0
# Multiple carriers                    13039603.0
# Multiple carriers Premium economy      148445.0
# SpiceJet                              3551974.0
# Trujet                                   4140.0
# Vistara                               3742221.0
# Vistara Premium economy                 26887.0
# Name: Price, dtype: float64

# %%
df01_sorted = df01.sort_values(ascending=False)
type(df01_sorted)
# Out:
# pandas.Series

# %%
type(df01_sorted)
# Out:
# pandas.Series

# %%
df01 = pd.DataFrame({'Airline': df01_sorted.index, 'Price': df01_sorted.values})
df01
# Out:
#                               Airline       Price
# 0                         Jet Airways  44824690.0
# 1                           Air India  16834015.0
# 2                   Multiple carriers  13039603.0
# 3                              IndiGo  11648071.0
# 4                             Vistara   3742221.0
# 5                            SpiceJet   3551974.0
# 6                            Air Asia   1787400.0
# 7                               GoAir   1137045.0
# 8                Jet Airways Business    350152.0
# 9   Multiple carriers Premium economy    148445.0
# 10            Vistara Premium economy     26887.0
# 11                             Trujet      4140.0

# %%
sns.barplot(x=df01['Airline'],y=df01['Price'],palette='Accent',errorbar=None)
plt.xticks(rotation=45)
plt.show()
# Out:
# C:\Users\SHIVRAJ SHINDE\AppData\Local\Temp\ipykernel_8736\246249520.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=df01['Airline'],y=df01['Price'],palette='Accent',errorbar=None)

# %%
sns.barplot(x=df01['Airline'],y=df01['Price'],palette='Accent',errorbar=None)
plt.xticks(rotation=45)
plt.show()
# Out:
# C:\Users\SHIVRAJ SHINDE\AppData\Local\Temp\ipykernel_8736\1337934949.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=df01['Airline'],y=df01['Price'],palette='Accent',errorbar=None)

# %%
# make plot horizontal

import seaborn as sns
sns.barplot(y=df['Airline'],x=df['Price'],palette='Accent',errorbar=None)
plt.xticks(rotation=45)
plt.show()
# Out:
# C:\Users\SHIVRAJ SHINDE\AppData\Local\Temp\ipykernel_8736\1221587868.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(y=df['Airline'],x=df['Price'],palette='Accent',errorbar=None)

# %%
# Add Hue of Source Multivariate
import seaborn as sns
plt.figure(figsize=(15,5))

sns.barplot(x=df['Airline'] ,y=df['Price'],hue=df['Source'],errorbar=None)
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# # CountPlot

# %%
# 
import seaborn as sns
plt.figure(figsize=(10,5))

ax = sns.countplot(x=df['Airline'],hue=df['Source'],width=.5)

ax.bar_label(ax.containers[0], fmt='%d', fontsize=8)
ax.bar_label(ax.containers[1], fmt='%d', fontsize=8)

plt.xticks(rotation=45)
plt.show()

# %%
# 
import seaborn as sns
plt.figure(figsize=(10,5))

sns.countplot(x=df['Airline'],hue=df['Source'])

plt.xticks(rotation=45)
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(15, 5))

sns.lineplot( data=df, x='Airline', y='Price', marker='o')

plt.title('Price by Airline')
plt.xticks(rotation=45)

plt.show()

# %%
plt.figure(figsize=(15,5))
sns.lineplot(y=df['Price'],x=df['Source'],hue=df['Airline'])
plt.show()

# %%
sns.scatterplot(df['Price'])
# Out:
# <Axes: ylabel='Price'>

# %%
sns.scatterplot(df['Price'])
# Out:
# <Axes: ylabel='Price'>

# %%
sns.scatterplot(y=df['Price'],x=df['Airline'])
# Out:
# <Axes: xlabel='Airline', ylabel='Price'>

# %%
plt.figure(figsize=(8,2))
sns.boxplot(x=df['Price'])
plt.xticks(rotation=45)
# Out:
# (array([-10000.,      0.,  10000.,  20000.,  30000.,  40000.,  50000.,
#          60000.,  70000.,  80000.,  90000.]),
#  [Text(-10000.0, 0, '−10000'),
#   Text(0.0, 0, '0'),
#   Text(10000.0, 0, '10000'),
#   Text(20000.0, 0, '20000'),
#   Text(30000.0, 0, '30000'),
#   Text(40000.0, 0, '40000'),
#   Text(50000.0, 0, '50000'),
#   Text(60000.0, 0, '60000'),
#   Text(70000.0, 0, '70000'),
#   Text(80000.0, 0, '80000'),
#   Text(90000.0, 0, '90000')])

# %%
plt.figure(figsize=(15,7))
sns.boxplot(x=df['Price'],y=df['Airline'])
# Out:
# <Axes: xlabel='Price', ylabel='Airline'>

# %%
plt.figure(figsize=(15,5))
sns.violinplot(x=df['Price'])
# Out:
# <Axes: xlabel='Price'>

# %%
plt.figure(figsize=(10,10))
sns.violinplot(x=df['Price'],y=df['Airline'])
# Out:
# <Axes: xlabel='Price', ylabel='Airline'>

# %%
plt.figure(figsize=(50,10))
sns.pairplot(df)
plt.show()

# %%
plt.figure(figsize=(8,5))
sns.kdeplot(df['Price'])
# Out:
# <Axes: xlabel='Price', ylabel='Density'>

# %%
plt.figure(figsize=(8,5))
sns.histplot(df['Price'],kde=True)
# Out:
# <Axes: xlabel='Price', ylabel='Count'>

# %%
sns.swarmplot(y=df['Price'],x=df['Airline'])
plt.xticks(rotation=45)
# Out:
# c:\Users\SHIVRAJ SHINDE\anaconda3\Lib\site-packages\seaborn\categorical.py:3399: UserWarning: 97.9% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# c:\Users\SHIVRAJ SHINDE\anaconda3\Lib\site-packages\seaborn\categorical.py:3399: UserWarning: 95.5% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# c:\Users\SHIVRAJ SHINDE\anaconda3\Lib\site-packages\seaborn\categorical.py:3399: UserWarning: 97.7% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# c:\Users\SHIVRAJ SHINDE\anaconda3\Lib\site-packages\seaborn\categorical.py:3399: UserWarning: 95.8% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# ...
