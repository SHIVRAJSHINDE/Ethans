# %%
import pandas as pd

data = {
'Student': ['S1', 'S2', 'S3', 'S4', 'S5','S6', 'S7', 'S8', 'S9', 'S10','S11', 'S12', 'S13', 'S14', 'S15','S16', 'S17', 'S18', 'S19', 'S20'],
'Marks': [35, 42, 48, 51, 55,58, 61, 64, 67, 70,72, 75, 78, 81, 84,86, 89, 91, 94, 98]
}

df = pd.DataFrame(data)
df
# Out:
#    Student  Marks
# 0       S1     35
# 1       S2     42
# 2       S3     48
# 3       S4     51
# 4       S5     55
# 5       S6     58
# 6       S7     61
# 7       S8     64
# 8       S9     67
# 9      S10     70
# 10     S11     72
# 11     S12     75
# 12     S13     78
# 13     S14     81
# 14     S15     84
# 15     S16     86
# 16     S17     89
# 17     S18     91
# 18     S19     94
# 19     S20     98

# %%
df.quantile(0.10)
# Out:
# ---------------------------------------------------------------------------
# ArrowNotImplementedError                  Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 df.quantile(0.10)
#
# File c:\Users\SHIVRAJ SHINDE\anaconda3\Lib\site-packages\pandas\core\frame.py:16132, in DataFrame.quantile(self, q, axis, numeric_only, interpolation, method)
#   16128         if not is_list_like(q):
#   16129             # BlockManager.quantile expects listlike, so we wrap and unwrap here
#   16130             # error: List item 0 has incompatible type "float | ExtensionArray |
#   16131             # ndarray[Any, Any] | Index | Series | Sequence[float]"; expected "float"
# > 16132             res_df = self.quantile(
#   16133                 [q],  # type: ignore[list-item]
#   16134                 axis=axis,
#   16135                 numeric_only=numeric_only,
#
# ...
