# %%
import pandas as pd

# %%
df =  pd.read_csv("E:/1.Eathans/Ethans/Data/CLT/clt_raw_population.csv")

df
# Out:
#       population_value
# 0             2.346340
# 1            15.050607
# 2             6.583728
# 3             4.564713
# 4             0.848124
# ...                ...
# 4995         11.384456
# 4996          0.635651
# 4997          1.986315
# 4998          8.457183
# 4999          4.547971
#
# [5000 rows x 1 columns]

# %%
import matplotlib.pyplot as plt
import seaborn as sns

mean_List = []

for i in range(1,100):
    SampDf = df.sample(n=150)
    mean_Value = SampDf['population_value'].mean().item()
    mean_List.append(mean_Value)


mean_List

sns.kdeplot(mean_List)
# Out:
# <Axes: ylabel='Density'>

# %%
import pandas as pd

# Ensure df is your dataframe
means_list = []
for i in range(1, 100):
    random_sample_rows = df.sample(n=150)
    mean_val = random_sample_rows['population_value'].mean().item()
    means_list.append(mean_val)

print(means_list[:5])  # Preview first 5 means
# Out:
# [4.259300258093555, 4.423825378966186, 5.014375675084639, 5.4869243531302425, 4.960108705443396]

# %%
import matplotlib.pyplot as plt
import seaborn as sns
plt.figure(figsize=(8, 5))
sns.kdeplot(means_list)
