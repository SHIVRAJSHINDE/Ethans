# %%
# pip install pandas

# %%
import pandas as pd

df = pd.read_csv("E:/1.Eathans/Ethans/Data/Airline/Data_Train_Airline.csv")
df
# Out:
#           ID      Airline Date_of_Journey    Source Destination  \
# 0          1       IndiGo      24-03-2019  Banglore   New Delhi
# 1          2    Air India      01-05-2019   Kolkata    Banglore
# 2          3  Jet Airways      09-06-2019     Delhi      Cochin
# 3          4       IndiGo      12-05-2019   Kolkata    Banglore
# 4          5       IndiGo      01-03-2019  Banglore   New Delhi
# ...      ...          ...             ...       ...         ...
# 10678  10679     Air Asia      09-04-2019   Kolkata    Banglore
# 10679  10680    Air India      27-04-2019   Kolkata    Banglore
# 10680  10681  Jet Airways      27-04-2019  Banglore       Delhi
# 10681  10682      Vistara      01-03-2019  Banglore   New Delhi
# 10682  10683    Air India      09-05-2019     Delhi      Cochin
#
#                        Route Dep_Time      Arrival_Time Duration Total_Stops  \
# 0                  BLR _ DEL    22:20  22-03-2026 01:10   2h 50m    non-stop
# 1      CCU _ IXR _ BBI _ BLR    05:50             13:15   7h 25m     2 stops
# 2      DEL _ LKO _ BOM _ COK    09:25  10-06-2026 04:25      19h     2 stops
# 3            CCU _ NAG _ BLR    18:05             23:30   5h 25m      1 stop
# 4            BLR _ NAG _ DEL    16:50             21:35   4h 45m      1 stop
# ...                      ...      ...               ...      ...         ...
# 10678              CCU ? BLR    19:55             22:25   2h 30m    non-stop
# 10679              CCU ? BLR    20:45             23:20   2h 35m    non-stop
# 10680              BLR ? DEL    08:20             11:20       3h    non-stop
# 10681              BLR ? DEL    11:30             14:10   2h 40m    non-stop
# 10682  DEL ? GOI ? BOM ? COK    10:55             19:15   8h 20m     2 stops
#
#       Additional_Info    Price
# 0             No info   3897.0
# 1             No info   7662.0
# 2             No info  13882.0
# 3             No info   6218.0
# 4             No info  13302.0
# ...               ...      ...
# 10678         No info   4107.0
# 10679         No info   4145.0
# 10680         No info   7229.0
# 10681         No info  12648.0
# 10682         No info  11753.0
#
# [10683 rows x 12 columns]

# %%
df.head(2)
# Out:
#    ID    Airline Date_of_Journey    Source Destination                  Route  \
# 0   1     IndiGo      24-03-2019  Banglore   New Delhi              BLR _ DEL
# 1   2  Air India      01-05-2019   Kolkata    Banglore  CCU _ IXR _ BBI _ BLR
#
#   Dep_Time      Arrival_Time Duration Total_Stops Additional_Info   Price
# 0    22:20  22-03-2026 01:10   2h 50m    non-stop         No info  3897.0
# 1    05:50             13:15   7h 25m     2 stops         No info  7662.0

# %%
df.isnull().sum()
# Out:
# ID                 0
# Airline            0
# Date_of_Journey    0
# Source             2
# Destination        2
# Route              3
# Dep_Time           0
# Arrival_Time       0
# Duration           0
# Total_Stops        1
# Additional_Info    0
# Price              3
# dtype: int64

# %%
df[df['Source'].isnull()]
# Out:
#           ID    Airline Date_of_Journey Source Destination Route Dep_Time  \
# 10660  10661    Vistara      21-03-2019    NaN         NaN   NaN    21:10
# 10661  10662  Air India      09-05-2019    NaN         NaN   NaN    13:00
#
#            Arrival_Time Duration Total_Stops Additional_Info  Price
# 10660  19-03-2026 00:05   2h 55m    non-stop         No info    NaN
# 10661             19:15   6h 15m      1 stop         No info    NaN

# %%
df['Source'].mode()[0]
# Out:
# 'Delhi'

# %%
new_Source_Value = df['Source'].mode()[0]

df.fillna({'Source':new_Source_Value},inplace=True)
# Out:
#           ID      Airline Date_of_Journey    Source Destination  \
# 0          1       IndiGo      24-03-2019  Banglore   New Delhi
# 1          2    Air India      01-05-2019   Kolkata    Banglore
# 2          3  Jet Airways      09-06-2019     Delhi      Cochin
# 3          4       IndiGo      12-05-2019   Kolkata    Banglore
# 4          5       IndiGo      01-03-2019  Banglore   New Delhi
# ...      ...          ...             ...       ...         ...
# 10678  10679     Air Asia      09-04-2019   Kolkata    Banglore
# 10679  10680    Air India      27-04-2019   Kolkata    Banglore
# 10680  10681  Jet Airways      27-04-2019  Banglore       Delhi
# 10681  10682      Vistara      01-03-2019  Banglore   New Delhi
# 10682  10683    Air India      09-05-2019     Delhi      Cochin
#
#                        Route Dep_Time      Arrival_Time Duration Total_Stops  \
# 0                  BLR _ DEL    22:20  22-03-2026 01:10   2h 50m    non-stop
# 1      CCU _ IXR _ BBI _ BLR    05:50             13:15   7h 25m     2 stops
# 2      DEL _ LKO _ BOM _ COK    09:25  10-06-2026 04:25      19h     2 stops
# 3            CCU _ NAG _ BLR    18:05             23:30   5h 25m      1 stop
# 4            BLR _ NAG _ DEL    16:50             21:35   4h 45m      1 stop
# ...                      ...      ...               ...      ...         ...
# 10678              CCU ? BLR    19:55             22:25   2h 30m    non-stop
# 10679              CCU ? BLR    20:45             23:20   2h 35m    non-stop
# 10680              BLR ? DEL    08:20             11:20       3h    non-stop
# 10681              BLR ? DEL    11:30             14:10   2h 40m    non-stop
# 10682  DEL ? GOI ? BOM ? COK    10:55             19:15   8h 20m     2 stops
#
#       Additional_Info    Price
# 0             No info   3897.0
# 1             No info   7662.0
# 2             No info  13882.0
# 3             No info   6218.0
# 4             No info  13302.0
# ...               ...      ...
# 10678         No info   4107.0
# 10679         No info   4145.0
# 10680         No info   7229.0
# 10681         No info  12648.0
# 10682         No info  11753.0
#
# [10683 rows x 12 columns]

# %%
df.isnull().sum()
# Out:
# ID                 0
# Airline            0
# Date_of_Journey    0
# Source             0
# Destination        2
# Route              3
# Dep_Time           0
# Arrival_Time       0
# Duration           0
# Total_Stops        1
# Additional_Info    0
# Price              3
# dtype: int64

# %%
df['Destination'].isnull().sum()

Dest_Value =df['Destination'].mode()[0]
Dest_Value
# Out:
# 'Cochin'

# %%
df.fillna({'Destination':Dest_Value},inplace=True)
df.isnull().sum()
# Out:
# ID                 0
# Airline            0
# Date_of_Journey    0
# Source             0
# Destination        0
# Route              3
# Dep_Time           0
# Arrival_Time       0
# Duration           0
# Total_Stops        1
# Additional_Info    0
# Price              3
# dtype: int64

# %%
df['Total_Stops'].isnull().sum()

df['Total_Stops'].mode()[0]
# Out:
# '1 stop'
