# %%
import pandas as pd

# %%
df = pd.read_csv("Data_Raw\Cleaned_Project_Churn_Modelling.csv")
df.head(2)
# Out:
#    RowNumber   Loan_ID  CustomerId   Surname Designation Education  \
# 0          1  LP001002    15634602  Hargrave     Manager  Graduate
# 1          2  LP001003    15647311      Hill  Sr Manager  Graduate
#
#   Self_Employed  CreditScore Credit_History Geography  ... HasCrCard  \
# 0            No          619            Yes    France  ...       Yes
# 1            No          608            Yes     Spain  ...        No
#
#   IsActiveMember Dependents  ApplicantIncome  CoapplicantIncome  \
# 0            Yes          0             5849                0.0
# 1            Yes          1             4583             1508.0
#
#     EstimatedSalary  Exited    Loan_Status No Customer LoanAmount
# 0           1,01,349      1  Loan Approved           1        959
# 1           1,12,543      0   Not Approved           1        525
#
# [2 rows x 28 columns]
