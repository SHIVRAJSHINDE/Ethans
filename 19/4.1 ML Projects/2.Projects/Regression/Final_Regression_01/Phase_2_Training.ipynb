# %% [markdown]
# # Read the DATA

# %%
import pandas as pd

# %%
X_test = pd.read_excel("Data_Train_Test\X_test.xlsx")
X_train = pd.read_excel("Data_Train_Test\X_train.xlsx")
y_test_true = pd.read_excel("Data_Train_Test\y_test_true.xlsx")
y_train_true = pd.read_excel("Data_Train_Test\y_train_true.xlsx")

# %%
# Read Transform
X_test_trans = pd.read_excel("Data_Trans\X_test_trans.xlsx")
X_train_trans = pd.read_excel("Data_Trans\X_train_trans.xlsx")

# %% [markdown]
# # Linear Regression Training

# %%
# Start Training
# Linear Regression

from sklearn.linear_model import LinearRegression

LinearRegressionOBJ = LinearRegression()

LinearRegressionOBJ.fit(X_train_trans,y_train_true)
# Out:
# LinearRegression()

# %%
# Save Linear Model
import joblib 
joblib.dump(LinearRegressionOBJ,"Model_Files/LinearModel.pkl")
# Out:
# ['Model_Files/LinearModel.pkl']

# %%
LinearModel_1 = joblib.load("Model_Files\LinearModel.pkl")

# %%
# PREDICT y_train_pred
# PREDICT y_test_pred
y_train_pred = LinearModel_1.predict(X_train_trans)
y_train_pred
# Out:
# array([[116377.30474493],
#        [113831.11284144],
#        [ 76042.01151239],
#        [ 60219.21128593],
#        [178797.05217119],
#        [118591.50886292],
#        [ 49339.69240356],
#        [135265.23023493],
#        [ 96229.00021739],
#        [164175.97033019],
#        [122106.50496056],
#        [  1404.05641278],
#        [136072.10844169],
#        [124662.44592762],
#        [ 76521.29554029],
#        [171353.30754293],
#        [171696.87555894],
#        [136005.97338565],
#        [271719.01287978],
#        [125099.70772509],
#        [118377.70413544],
#        [132432.68210148],
#        [ 67896.9104651 ],
#        [ 89360.68198072],
#        [ 68492.01239291],
#        [137158.95888814],
#        [ 95959.44064322],
#        [142124.8500433 ],
#        [ 87319.2355628 ],
#        [ 48241.86532538],
#        [221895.16403314],
#        [ 73531.73211214],
#        [172338.6420808 ],
#        [171895.68252207],
#        [141859.20940142],
#        [117746.65834524],
#        [131977.34864672],
#        [136041.57611141],
#        [ 97485.00123396],
#        [142605.65068101],
#        [158317.38938695],
#        [113253.65599074],
#        [ 75650.78643611],
#        [103807.86920735],
#        [131588.82901074],
#        [106931.83186002],
#        [169384.76623901],
#        [  4867.04581809],
#        [ 72668.41865956],
#        [ 95394.94293608],
#        [  3186.80571352],
#        [119997.53920612],
#        [124712.51087177],
#        [232465.8840598 ],
#        [174775.07866709],
#        [102444.03738338],
#        [ 93748.58608943],
#        [115604.28211271],
#        [114709.88374744],
#        [ 97719.03265726],
#        [123362.32867918],
#        [117208.96226662],
#        [ 84184.2851332 ],
#        [162302.50190727],
#        [426871.10375008],
#        [ 88853.61691111],
#        [160064.46977637],
#        [ 93855.92721018],
#        [ 36626.99322442],
#        [108546.03121308],
#        [102696.04281694],
#        [227843.65830701],
#        [ 39988.74433807],
#        [ 82231.3732266 ],
#        [131373.29858327],
#        [210584.32286042],
#        [197476.96732809],
#        [115098.22566066],
#        [130273.34055504],
#        [126722.15589122],
#        [214943.16386215],
#        [106154.19218443],
#        [189881.00954291],
#        [342294.21686748],
#        [167103.22917658],
#        [187946.35015314],
#        [106138.26797758],
#        [ 61568.428117  ],
#        [165126.27712698],
#        [139810.74500921],
#        [ 35911.6130153 ],
#        [150700.44257237],
#        [ 76368.47215371],
#        [205432.90197637],
#        [181954.91555571],
#        [119721.8593305 ]])

# %%
y_test_pred = LinearModel_1.predict(X_test_trans)

# %% [markdown]
# # Linear metrics Function

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error,r2_score
import numpy as np

def linear_Metrics(x_Data,True_Value,Pred_Value):

    MSE = mean_squared_error(True_Value,Pred_Value) 
    MAE = mean_absolute_error(True_Value,Pred_Value)
    RMSE = np.sqrt(MSE)
    R2 = r2_score(True_Value,Pred_Value)

    n = len(x_Data)
    p = x_Data.shape[1]
    A_R2 = 1-(1-R2)*(n-1)/(n-p-1)

    merticsDict = {"MSE": MSE,
                   "MAE":MAE,
                   "RMSE": RMSE,
                   "R2": R2,
                   "A_R2":A_R2}
    return merticsDict

# %%
# Training Evaluation
linear_Metrics(X_train,y_train_true,y_train_pred)
# Out:
# {'MSE': 1183774272.5226262,
#  'MAE': 22121.21604254766,
#  'RMSE': np.float64(34406.02087604183),
#  'R2': 0.7709186592540871,
#  'A_R2': 0.7554749733611043}

# %%
# Testing Evaluation
linear_Metrics(X_test,y_test_true,y_test_pred)
# Out:
# {'MSE': 5711948667.789251,
#  'MAE': 41762.12472052147,
#  'RMSE': np.float64(75577.43491141553),
#  'R2': 0.6638972734960762,
#  'A_R2': 0.545272781788809}

# %% [markdown]
# # Lasso Model Training

# %%
# Train using Lasso

from sklearn.linear_model import Lasso

LassoModel = Lasso(alpha=0.1)
LassoModel.fit(X_train_trans,y_train_true)
# Out:
# Lasso(alpha=0.1)

# %%
# import joblib file
import joblib

joblib.dump(LassoModel,"Model_Files/Lasso_Model.pkl")
# Out:
# ['Model_Files/Lasso_Model.pkl']

# %%
# Load the Lasso Model
Lasso_Model_1 = joblib.load("Model_Files/Lasso_Model.pkl")
Lasso_Model_1

Lasso_Model_1
# Out:
# Lasso(alpha=0.1)

# %%
# y_train_pred
y_train_pred = Lasso_Model_1.predict(X_train_trans)
y_train_pred
# Out:
# array([116378.2325393 , 113832.51470668,  76042.88511015,  60220.44222106,
#        178796.88699399, 118590.85869002,  49340.62186931, 135265.71323803,
#         96229.97371769, 164175.86876512, 122107.35813694,   1405.13341115,
#        136072.25471762, 124663.84874792,  76522.681416  , 171354.26341871,
#        171698.70652108, 136006.67398703, 271719.29487448, 125100.60312277,
#        118376.77695413, 132432.21680995,  67893.58429845,  89361.1821685 ,
#         68493.07090279, 137159.34862562,  95956.76770935, 142125.89065647,
#         87320.07502421,  48242.51026571, 221894.9790994 ,  73532.74895707,
#        172339.63510338, 171896.28337999, 141859.17160568, 117742.9573089 ,
#        131977.25397561, 136037.11491259,  97486.84996264, 142606.16728855,
#        158318.04640592, 113253.9725244 ,  75651.44819315, 103809.11764628,
#        131585.7168186 , 106932.86801174, 169384.81358536,   4868.14415377,
#         72669.86323841,  95392.07177369,   3188.18984024, 119998.34047716,
#        124712.75620182, 232465.97037881, 174775.56945554, 102445.13391969,
#         93749.01136439, 115604.48581685, 114706.29153275,  97719.90477432,
#        123362.68733663, 117209.60475266,  84184.97934928, 162302.86808058,
#        426870.52179679,  88853.97599736, 160060.35813747,  93856.21817964,
#         36628.22459791, 108541.95322027, 102696.34705542, 227842.84109654,
#         39989.20163447,  82232.32559309, 131373.48779762, 210585.03714714,
#        197473.34944216, 115094.39744088, 130274.97463782, 126719.46985501,
#        214940.46430911, 106153.97962424, 189880.84038858, 342294.35258047,
#        167103.91838543, 187946.91185427, 106138.67585525,  61569.58273682,
#        165126.66371643, 139807.46665375,  35911.92866347, 150701.11828614,
#         76369.3426812 , 205432.49470369, 181955.89863602, 119722.42044946])

# %%
# y_test_pred
y_test_pred = Lasso_Model_1.predict(X_test_trans)
y_test_pred
# Out:
# array([ 70916.95105635, 123258.38513582,  62315.81286324, 178311.48082358,
#         49766.87659127,  72768.30996648, 175220.89875303,  53218.16676704,
#         65025.75205901, 381900.05884505,  99720.42462466, 164273.66032613,
#        150051.23722238,  96313.43330036,  91704.4958998 , 137817.91381257,
#        178510.02019447, 108891.8554622 , 182672.73026586, 300030.40243965,
#        115936.36888108,  89464.70321421,  71972.29706456, 143834.35012968])

# %%
# Trainig DATA Evaluation
linear_Metrics(X_train,y_train_true,y_train_pred)
# Out:
# {'MSE': 1183774274.863149,
#  'MAE': 22121.13878265978,
#  'RMSE': np.float64(34406.0209100551),
#  'R2': 0.7709186588011544,
#  'A_R2': 0.7554749728776368}

# %%
# Test Evaluation

linear_Metrics(X_test,y_test_true,y_test_pred)
# Out:
# {'MSE': 5711987807.773911,
#  'MAE': 41762.18885249379,
#  'RMSE': np.float64(75577.69385059267),
#  'R2': 0.6638949704194337,
#  'A_R2': 0.5452696658615868}

# %% [markdown]
# # DTR training

# %%
from sklearn.tree import DecisionTreeRegressor

DTR_Obj = DecisionTreeRegressor()
DTR_Obj.fit(X_train_trans,y_train_true)
# Out:
# DecisionTreeRegressor()

# %%
# Save the Model in Model_Files
import joblib
joblib.dump(DTR_Obj,"Model_Files/DTR_Obj.pkl")
# Out:
# ['Model_Files/DTR_Obj.pkl']

# %%
# Genereate y_train_pred and y_test_pred

DTR_Obj_01 = joblib.load("Model_Files/DTR_Obj.pkl")

# %%
# Genereate y_train_pred 
y_train_pred = DTR_Obj_01.predict(X_train_trans)
y_train_pred
# Out:
# array([ 78100., 146000.,  98500.,  60000., 167400., 126200.,  94700.,
#        129600., 110600., 146800.,  93300.,  28000., 142400., 155300.,
#         65000., 152800., 157800., 131000., 235200., 122800., 117800.,
#        111100.,  93100.,  76700.,  81300., 115300.,  81700., 134100.,
#        106300.,  70700., 218200.,  55000., 162400., 168900.,  97900.,
#        136800., 109400., 139200., 107000., 118200., 310000., 118500.,
#        100400., 101200., 137200., 115100., 134700.,  25000.,  65600.,
#         77000.,  32500., 131100., 126300., 239300., 169900., 109800.,
#        104700.,  96600.,  80000.,  92700., 133300.,  99400.,  93100.,
#        138200., 480000.,  98000., 151300.,  87800.,  40000., 119200.,
#         98300., 395000.,  71400.,  95100.,  90000., 212200., 171800.,
#        113800., 139400., 111000., 290000.,  89600., 145500., 380000.,
#        142800., 159100., 121700.,  58000., 151000., 119900.,  72100.,
#         40000.,  76900., 168900., 149700.,  55000.])

# %%
# Genereate y_test_pred
y_test_pred = DTR_Obj_01.predict(X_test_trans)
y_test_pred
# Out:
# array([119200., 133300.,  65600., 168900.,  71400., 119200., 131000.,
#         65600.,  78100., 395000., 101200., 149700., 218200.,  98300.,
#        110600.,  65000.,  60000., 110600., 168900., 395000., 133300.,
#        134700.,  81700., 149700.])

# %%
#  Evaluatoin Training Data
linear_Metrics(X_train,y_train_true,y_train_pred)
# Out:
# {'MSE': 0.0, 'MAE': 0.0, 'RMSE': np.float64(0.0), 'R2': 1.0, 'A_R2': 1.0}

# %%
# Evaluation on Testing Data
linear_Metrics(X_test,y_test_true,y_test_pred)
# Out:
# {'MSE': 6532262500.0,
#  'MAE': 41566.666666666664,
#  'RMSE': np.float64(80822.41335174297),
#  'R2': 0.6156283320838933,
#  'A_R2': 0.4799677434076204}
