# %% [markdown]
# # <h1 style="color:#2a9d8f; font-family:Candara, sans-serif; text-align:left; margin:-60px 0 0 0; padding:0;">Python Pandas</h1>

# %% [markdown]
# <div style="color:#2a9d8f; font-family:Candara, sans-serif; font-size:15px; line-height:1.2; margin:0; padding:0;">
# <p style="margin:0; padding:0;"><b>Pandas</b> is a powerful Python library used for data sets. It provides functions for:</p>
# <ul style="margin:0 0 0 20px; padding:0;">
#     <li><b>Analyzing</b></li>
#     <li><b>Cleaning</b></li>
#     <li><b>Exploring</b></li>
#     <li><b>Manipulating</b> data</li>
# </ul>
# <p style="margin:0; padding:0;">Named after <i>"Panel Data"</i> and <i>"Python Data Analysis"</i> (Wes McKinney, 2008), Pandas allows us to clean messy data sets and analyze big data based on statistical theories—making data readable, relevant, and ready for Data Science.</p>
# <p style="margin:0; padding:0;">Usually, we work with two types of datasets:</p>
# <ul style="margin:0 0 0 20px; padding:0;">
#     <li><b>Series</b> (1D)</li>
#     <li><b>DataFrame</b> (2D)</li>
# </ul>
# </div>l>
# </div>m['b'])  # Output: 20t(s_custom['b'])  # Output: 20

# %% [markdown]
# # <h2 style="color: #2a9d8f; font-family: 'Candara', sans-serif; font-weight: bold; text-align: left; margin:-60px 0 0 0; padding-bottom: 10px; border-bottom: 2px solid #264653;">Installing Pandas</h2>
# >
#    </li>
# </ul>

# %% [markdown]
# <p style="color: #264653; font-family: 'Candara', sans-serif; font-siz6: 18px; line-height: 1; margin-top: 0;">
# To install Pandas, use one of the following commands depending on your package manager:
# </p>
#
# <ul style="font-family: 'Candara', sans-serif; font-size: 18px; line-height: 1; padding-left: 20px; margin-top: 0; list-style-type: none;">
#     <li style="color: #2a9d8f; margin-bottom: 0;"><b>Using pip:</b><br>
#         <code>pip install pandas</code><br>
#         <code>!pip install pandas</code>
#     </li>
#     <li style="color: #2a9d8f; margin-bottom: 0;"><b>Using pip3:</b><br>
#         <code>pip3 install pandas</code>
#     </li>
#     <li style="color: #2a9d8f; margin-bottom: 0;"><b>Using Conda:</b><br>
#         <code>conda install pandas</code>
#     </li>
# </ul>

# %%
pip install pandas

# %% [markdown]
# # <h2 style="color: #2a9d8f; font-family: 'Candara', sans-serif; font-weight: bold; text-align: left;margin:-60px 0 0 0; padding-bottom: 10px; border-bottom: 2px solid #264653;"> Series </h2>

# %% [markdown]
# <p style="color: #2a9d8f; font-family: 'Candara', sans-serif; font-size: 16px; margin: 0; padding: 0;">
#     A Pandas Series is a one-dimensional labeled array capable of holding any data type (e.g., integers, floats, strings).
#     It is similar to a Python list or NumPy array but provides additional functionalities and features.
#     Each element in a Series is associated with an index, which labels the elements and allows for efficient data retrieval and manipulation.
# </p>

# %%
import pandas as pd
listOne = [1, 7, 2]
seriesOne = pd.Series(listOne)
seriesOne

# %%
import pandas as pd

listOne = (1,2,3,4,5)
listOne
sereisOne = pd.Series(listOne)

print(sereisOne)

type(sereisOne)

# %%
# Create the Series uisng Dictinary Pandas

calories = {"day1": 420, "day2": 380, "day3": 390}
calSeries = pd.Series(calories)
calSeries

# %% [markdown]
# # <h2 style="color: #2a9d8f; font-family: 'Candara', sans-serif; font-weight: bold; text-align: left;margin:-60px 0 0 0; padding-bottom: 10px; border-bottom: 2px solid #264653;">DataFrame </h2>

# %% [markdown]
# <p style="color: #2a9d8f; font-family: 'Candara', sans-serif; font-size: 16px; margin: 0; padding: 0;">
#     In pandas, a <b>DataFrame</b> is a two-dimensional labeled data structure, similar to a table or spreadsheet. It consists of rows and columns, where each column can contain data of different types (e.g., integers, floats, strings, etc.). DataFrames are incredibly versatile and are widely used for data manipulation, analysis, and exploration in Python.
# </p>

# %%
# Create Dataframe from Dictionary

data = {"calories" : [420, 380, 390],
        "duration" : [50,  40,   45]   }
df = pd.DataFrame(data)
df

# %%
newDict = {'StudentName': ["Rajesh","Sunil","prakash"],
          'marks':[99,100,98]}

newDict
df = pd.DataFrame(newDict)

df

# %%
ListOne = [['Pune',42],
          ['Mumbai',39],
          ['Bangalore',40]]

ListOne

df = pd.DataFrame(ListOne,columns=['Cities','Temp'])

df

# %%
# Create Dataframe from List

listInsideLIST =  [ ["Alice", 25],
                   ["Bob", 30],
                   ["Charlie", 22],
                   ["David", 35]   ]


pd.DataFrame(listInsideLIST,columns=['Name',"Age"])

# %%
'''Python | Creating DataFrame from dict of lists '''
'''Python | Creating DataFrame from dict of narray '''

newDict = { 'name': ['Alice', 'Bob', 'Charlie', 'David'], 
            'age':  [25, 30, 22, 35]}

pd.DataFrame(newDict)

# %% [markdown]
# # <h2 style="color: #2a9d8f; font-family: 'Candara', sans-serif; font-weight: bold; text-align: left;margin:-60px 0 0 0; padding-bottom: 10px; border-bottom: 2px solid #264653;"> Reading and Saving DataFrame</h2>
# abase.</li>
# </ul>

# %% [markdown]
# <h3 style="color:#2a9d8f; font-family:Candara, sans-serif; font-size:19px; margin:0; padding-top:10px;">
# Data Input:
# </h3>
# <ul style="font-family:Candara, sans-serif; font5size:17px; margin:0 0 0 20px; padding:0; list-style-type:square;">
#     <li><b>read_csv()</b> : Read a CSV file into a DataFrame.</li>
#     <li><b>read_excel()</b> : Read an Excel file into a DataFrame.</li>
#     <li><b>read_json()</b> : Read a JSON file into a DataFrame.</li>
#     <li><b>read_sql()</b> : Read from a SQL database into a DataFrame.</li>
# </ul>
#
# <h3 style="color:#2a9d8f; font-family:Candara, sans-serif; font-size:19px; margin:0; padding-top:10px;">
# Save File:
# </h3>
# <ul style="font-family:Candara, sans-s5rif; font-size:17px; margin:0 0 0 20px; padding:0; list-style-type:square;">
#     <li><b>to_csv()</b> : Write a DataFrame to a CSV file.</li>
#     <li><b>to_excel()</b> : Write a DataFrame to an Excel file.</li>
#     <li><b>to_json()</b> : Write a DataFrame to a JSON file.</li>
#     <li><b>to_sql()</b> : Write records stored in a DataFrame to a SQL database.</li>
# </ul>

# %%
FilePath = "D:/Old Projects/MLProjects/ZDatasets/DummyData/Data_Train1.csv"

df = pd.read_csv(FilePath)

df

# %%
FilePath = "D:/Old Projects/MLProjects/ZDatasets/DummyData/Data_Train_Airline.xlsx"

df = pd.read_excel(FilePath)

df

# %%
import pandas as pd 
file_path = "D:/Old Projects/MLProjects/ZDatasets/DummyData/Train_Data.xlsx"
df1 = pd.read_excel(file_path)
df = df1

# %% [markdown]
# # <h2 style="color: #2a9d8f; font-family: 'Candara', sans-serif; font-weight: bold; text-align: left;margin:-60px 0 0 0; padding-bottom: 0px; border-bottom: 2px solid #264653;">  Data Exploration
# </h2>
#     </li>
# </ul>

# %% [markdown]
# <ul style="font-family: 'Candara', sans-serif; font-size: 18px; line-height: 1; padding-left: 20px; margin-top: 0; list-style-type: none;">
#     <li style="color: #2a9d8f; margin-bottom: 0;">
#         <code>df.info()</code> — Displays summary of DataFrame including index, columns, non-null values, and data types.
#     </li>
#     <li style="color: #2a9d8f; margin-bottom: 0;">
#         <code>df.describe()</code> — Generates descriptive statistics for numeric columns (count, mean, std, min, max, etc.).
#     </li>
#     <li style="color: #2a9d8f; margin-bottom: 0;">
#         <code>df.columns</code> — Lists all column names of the DataFrame.
#     </li>
#     <li style="color: #2a9d8f; margin-bottom: 0;">
#         <code>df['columnName'].unique()</code> — Returns all unique values in a specific column.
#     </li>
#     <li style="color: #2a9d8f; margin-bottom: 0;">
#         <code>df.value_counts()</code> — Returns counts of unique rows or values in a Series.
#     </li>
# </ul>

# %%
# df.head(n): Retrieves the first n records of the dataset (defaults to 5).
# df.tail(n): Retrieves the final n records of the dataset.
# df.mean() / df.median() / df.mode(): Calculates individual baseline operational metrics across designated axes.
# df.value_counts()
# df['column'].value_counts(): Counts the absolute frequency of every unique entry in a specified feature.
# df.nunique(): Counts total unique entries across rows or columns.
# df['column'].unique(): Isolates and outputs an array of all distinct values within a column.

# %%
df.nunique()

# %%
df['Age'].value_counts()

# %%
df.info()

# %%
df.describe()

# %%
df.columns

# %%
df['Airline'].value_counts()

# %%
df['City'].value_counts()

# %%
df.nunique()

# %%
df['Airline'].unique()

# %% [markdown]
# /p>
#     </li>
# </ol>

# %% [markdown]
# # <h2 style="color: #2a9d8f; font-family: 'Candara', sans-serif; font-weight: bold; text-align: left;margin:-60px 0 0 0; padding-bottom: 0px; border-bottom: 2px solid #264653;">  Types of Filtering
# </h2>
#     </li>
# </ul>
#
#
#
# <ul style="color:#264653; font-family:Candara, sans-serif; font-size:16px; line-height:1.6; margin-top:10px;">
#     <li><strong>Simple Filtering</strong></li>
#     <li><strong>Conditional Filtering</strong></li>
#
# </ul>/ol>

# %% [markdown]
# # <h2 style="color: #2a9d8f; font-family: 'Candara', sans-serif; font-weight: bold; text-align: left; margin: -60px 0 0 30px; padding-bottom: 0px; border-bottom: 2px solid #264653;">  Simple Filtering
# </h2>
#     </li>
# </
# ul>

# %% [markdown]
# <ul style="font-family:Candara, sans-serif; font-size:18px; line-height:1.0; padding-left:15px; margin:0px 0 0 0; list-style-type:none;">
#     <li style="color:#2a9d8f; margin-bottom:2px;">
#         <b>Column Filtering</b><br>
#         <ul style="font-family:Candara, sans-serif; font-size:14px; line-height:0.1; padding-left:15px; margin:0px 0 0 0; list-style-type:none;">
#             <p style="margin:0 0 0 20px;">Syntax: <code>df[['column1', 'column2']]</code></p>
#             <p style="margin:0 0 0 20px;">Example: <code>df[['FirstName', 'LastName']]</code></p>
#         </ul>
#     </li>
# </ul>
#
#
# <ul style="font-family:Candara, sans-serif; font-size:18px; line-height:1.1; padding-left:15px; margin:0px 0 0 0; list-style-type:none;">
#     <li style="color:#2a9d8f; margin-bottom:10px;">
#         <b>Row Filtering (Slicing by Position)</b><br>
#         <ul style="font-family:Candara, sans-serif; font-size:14px; line-height:0.0; padding-left:0px; margin:0px 0 0 0; list-style-type:none;">
#             <p style="margin:0 0 0 20px;">Syntax: <code>df[startRow:endRow]</code></p>
#             <p style="margin:0 0 0 20px;">Example: <code>df[2:4]</code></p>
#         </ul>
#     </li>
# </ul>
#
#
# <ul style="font-family:Candara, sans-serif; font-size:18px; line-height:1.4; padding-left:15px; margin:0px 0 0 0; list-style-type:none;">
#     <li style="color:#2a9d8f; margin-bottom:10px;">
#         <b>Row & Column Filtering</b>
#         <ul style="font-family:Candara, sans-serif; font-size:14px; line-height:1.4; padding-left:15px; margin:0px 0 0 0; list-style-type:none;">
#             <b>.loc (Label-Based Indexing)</b><br>
#             <p style="margin:0 0 0 20px;">Syntax: <code>df.loc[rowLabels, ['ColumnNames']]</code></p>
#             <p style="margin:0 0 0 20px;">Example: <code>df.loc[2:4, ['FirstName', 'LastName']]</code></p>
#             <b>.iloc (Integer-Position Indexing)</b><br>
#             <p style="margin:0 0 0 20px;">Syntax: <code>df.iloc[rowIndex, columnIndexNumbers]</code></p>
#             <p style="margin:0 0 0 20px;">Example: <code>df.iloc[2:4, 1:3]</code></p>
#         </ul>
#     </li>
# </ul>

# %%
import pandas as pd

file_path = "D:/Old Projects/MLProjects/ZDatasets/DummyData/Data_Train1.csv"
df = pd.read_csv(file_path)

df

# %%
# Column Filter

columlist = ['First_name','City']


df.loc[0:4,columlist]

# %%
# Row Filtering
df[0:4]

# %%
# Row And Column Filtering
# Syntax df.loc[RowIndexNumber,[ColumnNames]]


ColumnList = ['City','Airline']


df.loc[0:4,ColumnList]

# %%
df

# %%
# Row And Column Filtering
# Syntax df.iloc[RowIndexNumber,ColumnIndexNumber]

df.iloc[0:4,0:3]

# %% [markdown]
# l>

# %% [markdown]
# f.iloc[2:4, 1:2]`

# %% [markdown]
# de>
#         </p>
#     </li>
# </ol>

# %%
# print all the row starting from 2 ending at 4th index No.
df[3:10]

# %%
df

# %% [markdown]
# <ol style="font-family: 'Candara', sans-serif; font-size: 18px; line-height: 1.8; padding-left: 20px; margin-top: 10px; list-style-type: decimal;">
#     <li style="color: #2a9d8f;"><b>.loc</b>
#     <p style="color: #2a9d8f; font-family: 'Candara', sans-serif; font-size: 16px; margin: 0;">
#         <i>Syntax:</i> <code>df.loc[rowNumbers, [ColumnNames]]</code><br>
#         <i>Example:</i> <code>df.loc[2:4, ["Firstname", "LastName"]]</code>
#     </p>
# </li>

# %%
# df.loc[rowNumbers,[ColumnName]]
df.loc[1,['First_name','City']]

# %%
df.loc[:5,['Full Name','Date_of_Journey']]

# %% [markdown]
# <ol style="font-family: 'Candara', sans-serif; font-size: 18px; line-height: 1.8; padding-left: 20px; margin-top: 10px; list-style-type: decimal;">
#     <li style="color: #2a9d8f;"><b>.iloc</b>
#         <p style="color: #2a9d8f; font-family: 'Candara', sans-serif; font-size: 16px; margin: 0;">
#             <i>Syntax:</i> <code>df.iloc[rowNumbers, [ColumnIndexNumbers]]</code><br>
#             <i>Example:</i> <code>df.iloc[2:4, 1:2]</code>
#         </p>
#     </li>
# </ol>

# %%
# Filtering using iloc
# df.iloc[rowNumber,[columnNumber]]

df.iloc[0:2,[1,2,3]]
df.iloc[0:2,[1,2]]

df.iloc[1:3,rg]

# %%
rg = range(0,4)
print(rg)
df.iloc[1:3,rg]

# %% [markdown]
# </ol>

# %% [markdown]
# # <h2 style="color: #2a9d8f; font-family: 'Candara', sans-serif; font-weight: bold; text-align: left; margin: -60px 0 0 30px; padding-bottom: 0px; border-bottom: 2px solid #264653;">  Conditional Filtering </h2>
#
#   >

# %% [markdown]
# <p style="color:#264653; font-family:Candara, sans-serif; font-si5e:17px; margin:0; padding-top:10px;">
# <i>Create the condition:</i><br>
# <code>cond01 = df["Age"] >= 42</code><br>
# <code>cond02 = df['Airline'] == "Jet Airways"</code>
# </p>
#
# <ul style="font-family:Candara, sans-serif; f5nt-size:16px; margin:0 0 0 20px; padding:0; list-style-type:disc;">
#     <li style="color:#2a9d8f;">
#         <i>Insert into Indexing and Slicing:</i><br>
#         <code>df[cond01 & cond02]</code>
#     </li>
#     <li style="color:#2a9d8f;">
#         <i>Insert into .loc:</i><br>
#         <code>df.loc[cond01 & cond02, [ColumnNames]]</code><br>
#         <i>Example:</i> <code>df.loc[cond01 & cond02, ["Firstname", "LastName"]]</code>
#     </li>
#     <li style="color:#2a9d8f;">
#         <i>Insert into .iloc:</i><br>
#         <code>df.iloc[IndexNumber, [ColumnIndexNumbers]]</code><br>
#         <i>Example:</i> <code>df.iloc[IndexNumber, 1:2]</code>
#     </li>
# </ul>

# %%
import pandas as pd

file_path = "D:/Old Projects/MLProjects/ZDatasets/DummyData/Data_Train1.csv"
df = pd.read_csv(file_path)
df
RowCondi1 = df['Airline']=='IndiGo'
RowCondi2 = df['Last_name'] == 'Kumar'
df[RowCondi1 & RowCondi2]

# %%
# df.loc[Conditions,['NamesofColumns']]

RowCondi1 = df['Airline']=='IndiGo'
RowCondi2 = df['Last_name'] == 'Kumar'
NameOfColumns = ['First_name','Last_name','Age']

df.loc[RowCondi1 & RowCondi2,NameOfColumns]

# %%
df

# df.iloc[IndexNumber, 1:2]

con1=df["City"]=="BANGALURU"
con2=df["Airfare"]>7000
con3=df["Airline"]=="Jet Airways"

IndexNumber = df[con1|con2|con3].index
columnIndexNumber = [0,1,2]

print(IndexNumber)

df.iloc[IndexNumber,columnIndexNumber]

# %%
IndexNumber  = df[con1|con2|con3].index

# %%
df.loc[con1 | con2 | con3,ColumnList02]

# %%
# df.iloc

# %%
# Filter Data
# city is BANGALURU OR 
# AIRFARE IS GREATER THAN 7000 OR 
# Airline is Jet Airways
# column Full Nane

# COnditional Filtering with loc

# Syntax : df.loc[Codition,[ColumnNames]]


Cond01 = df["Age"]<=42
cond02 = df["Airline"]=="IndiGo"
Columlist01 = ['First_name','Last_name','Age']


df.loc[Cond01 & cond02,Columlist01]

# %%
# create condtion

cond01 = df['Airline']=="IndiGo"
# indexing and slicing
df[cond01]

# %%
# df.loc[cond01 & cond02, [ColumnNames]]

cond01 = df['Airline']=="IndiGo"
cond02 = df['Last_name']=="Gandhi"

df.loc[cond01&cond02,['Full Name','Airfare','Airline']]

# %%
# df.loc[cond01 & cond02, [ColumnNames]]

cond01 = df['Airline']=="IndiGo"
cond02 = df['Last_name']=="Gandhi"

indexNumber = df[cond01&cond02].index
indexNumber
df.iloc[indexNumber,[1,2,3]]

# %%
# Multiple Condtion
cond01 = df["Age"]>=42
cond02 = df['Airline']=="IndiGo"

df[cond01 | cond02]

# %%
df[cond01 & cond02]

# %%
# filter data where age is greater that 40 and Airline is Jet Airways
cond01 = df['Age']>=40
cond02 = df['Airline']=="IndiGo"
df[ cond01 & cond02]

# %%
# filter data where age is greater that 43 or Airline is Jet Airways

cond01 = df['Age']>=42
cond02 = df['Airline']=="Multiple carriers"
df[ cond01 | cond02]

# %%
# create condtion
# retrive the index from the created condition
# pass the codition inside the dataframe

# %%
df[df["Age"]>45].index

# %%
indexNumbers01 = df[df["Age"]>45].index
indexNumbers01

# %%
df.loc[indexNumbers01,["First_name","Last_name","Age",'Date_of_Journey']]

# %%
df

# %%
cond01 = df['Age']>=42
cond02 = df['Airline']=="IndiGo"
df[cond01&cond02]

# %%
df.loc[cond01&cond02,['Date_of_Journey','Dep_Time']]

# %%
ind = df[cond01&cond02].index

df.iloc[ind,[6,7]]

# %%
df.iloc[indexNumbers01,[0,1,2]]

# %% [markdown]
# # <h2 style="color: #2a9d8f; font-family: 'Candara', sans-serif; font-weight: bold; text-align: left;margin:-60px 0 0 0; padding-bottom: 10px; border-bottom: 2px solid #264653;"> Handling Missing Values </h2>
#
#
#
#
# <p style="color: #264653; font-family: 'Candara', sans-serif; font-size: 18px; line-height: 1.5; margin-top: 15px;">
#     Handling missing values is an essential step in data cleaning. Pandas provides two primary methods for dealing with missing data: <code>fillna()</code> and <code>dropna()</code>.
#
# </p>ul>

# %% [markdown]
# # <h2 style="color: #2a9d8f; font-family: 'Candara', sans-serif; font-weight: bold; text-align: left;margin:-60px 0 0 30px; padding-bottom: 10px; border-bottom: 2px solid #264653;">.fillna </h2>

# %% [markdown]
# <li style="color: #2a9d8f; margin-bottom: 0;"><b></b>
# <ul style="margin: 0; padding-left: 15px; list-style-type: none;">
# <li style="margin-bottom: 0;"><code>df.fillna(0)</code> — Replace all NaNs with 0.</li>
# <li style="margin-bottom: 0;"><code>df.fillna(method='ffill')</code> — Forward fill using last valid value.</li>
# <li style="margin-bottom: 0;"><code>df.fillna(method='bfill')</code> — Backward fill using next valid value.</li>
# <li style="margin-bottom: 0;"><code>df.fillna({'col1':0,'col2':1})</code> — Fill NaNs in 'col1' and 'col2' with 0 and 1.</li>
# </ul>
# </li>
#
#
# <p style="color: #264653; font-family: 'Candara', sans-serif; font-size: 18px; line-height: 1; margin-top: 0;">
#
# </p>
#
# </ul>
# </li>
#
# </ul>

# %%
df
df.isna().sum()

file_path = "D:/Old Projects/MLProjects/ZDatasets/DummyData/Data_Train1.csv"
df = pd.read_csv(file_path)

df

# %%
df.isnull().sum()



meanAge = df['Age'].mean()
modeAirline = df['Airline'].mode()

# df.fillna({'col1':0,'col2':1}) — Fill NaNs in 'col1' and 'col2' with 0 and 1.
df.fillna({'Age':meanAge,'Airline':modeAirline},inplace=True)

print(df)

# %%
meanOfAge = df['Age'].mean()

df['Age'].fillna(meanOfAge,inplace=True)

# %%
modeOfAirline = df['Airline'].mode()

df['Airline'].fillna(modeOfAirline,inplace=True)
df

# %%
# Apply Median on Age send me the code
med_ofAge=df['Age'].median()
med_ofAge

# %%
df['Age'].fillna(med_ofAge, inplace=True)

# %%
meanAge = df['Age'].mean()
df['Age'].fillna(meanAge,inplace=True)


modeOfAirline = df['Airline'].mode()
df['Airline'].fillna(modeOfAirline,inplace=True)
df

# %%
df['Airline'].mode()

# %%
newDf = df.fillna(method="ffill")
newDf

# %%
df

# %%
newDf = df.fillna(method="bfill")
newDf

# %%
# mean averange
# median averange of central two values
Odd = [1,2,3,4,5]
(3)/1
Evel = [1,2,3,4]
(2,3)/2

# mode: Most frequent

# %%
meanValue = df["Age"].mean() # average
meanValue

new_df = df['Age'].fillna(meanValue)

new_df

# %%
medianValue = df["Age"].median() # average
print(medianValue)

df['Age'].fillna(medianValue)

# %%
modeValue = df["Airline"].mode()
print(modeValue)

# %%
df['Airline'].fillna(modeValue[0])

# %%
newDf = df.fillna(modeValue[0])
newDf

# %% [markdown]
# # <h2 style="color: #2a9d8f; font-family: 'Candara', sans-serif; font-weight: bold; text-align: left;margin:-60px 0 0 30px; padding-bottom: 10px; border-bottom: 2px solid #264653;">.dropna</h2>

# %% [markdown]
# <div style="
#     background-color: #f4f9f8;
#     border-left: 6px solid #2a9d8f;
#     padding: 20px;
#     border-radius: 0 8px 8px 0;
#     margin: 15px 0;
#     font-family: 'Candara', 'Segoe UI', sans-serif;
# ">
#     <p style="color: #264653; font-size: 18px; line-height: 1.4; margin-top: 0; margin-bottom: 15px; font-weight: bold;">
#         The <code>dropna</code> method removes missing values, while <code>fillna</code> fills missing values in a DataFrame or Series with a specified value or method.
#     </p>
#
# <hr style="border: 0; border-top: 1px solid #d2e6e3; margin: 15px 0;">
#
# <ul style="margin: 0; padding-left: 20px; font-size: 15px; color: #264653; line-height: 1.8;">
#     <li style="margin-bottom: 1px;"><code>df.dropna()</code> — Drop rows where any value is NaN.</li>
#     <li style="margin-bottom: 1px;"><code>df.dropna(axis=1)</code> — Drop columns where any value is NaN.</li>
#     <li style="margin-bottom: 0;"><code>df.dropna(subset=['col1','col2'])</code> — Drop rows where NaNs appear in 'col1' or 'col2'.</li>
# </ul>
# </div>2

# %%
import pandas as pd

file_path = "D:/Old Projects/MLProjects/ZDatasets/DummyData/Data_Train1.csv"
df = pd.read_csv(file_path)

df


df.dropna(axis=1)

# %%
df.dropna(axis=0,how='all')

# %%
df

# %%
df.dropna(inplace = True)
df

# %%
import pandas as pd

file_path = "D:\\MLProjects\\ZDatasets\\DummyData\\Data_Train1.csv"
df = pd.read_csv(file_path)

df

# %%
import numpy as np

new_df = df.replace(np.NaN,10)
new_df

# %% [markdown]
# #
# <h2 style="color: #2a9d8f; font-family: 'Candara', 'Segoe UI', sans-serif; font-weight: bold; text-align: left; margin:-60px 0 0 0; padding-bottom: 10px; border-bottom: 2px solid #264653;">
#     Combining DataFrames – Merging Operations
# </h2>>

# %% [markdown]
# /li>
#     </ul>
# </div>

# %% [markdown]
# <div style="
#     background-color: #f7faf9;
#     border: 1px solid #d2e6e3;
#     border-left: 6px solid #2a9d8f;
#     padding: 20px;
#     border-radius: 4px;
#     margin: 15px 0;
#     font-family: 'Candara', 'Segoe UI', sans-serif;
# ">
#     <p style="color: #264653; font-size: 18px; line-height: 1.4; margin-top: 0; margin-bottom: 20px;">
#         Merge two DataFrames based on a key column using the <code>pd.merge()</code> function.
#     </p>
#
# <h3 style="color: #2a9d8f; font-size: 18px; margin-top: 0; margin-bottom: 8px; font-weight: bold;">Syntax</h3>
# <pre style="background-color: #ffffff; border: 1px solid #e1e8e7; padding: 10px; border-radius: 4px; font-family: monospace; font-size: 14px; margin-bottom: 20px; color: #264653;">pd.merge(left_Df, right_df, left_on='name1', right_on='name2', how='outer')</pre>
#
# <h3 style="color: #2a9d8f; font-size: 18px; margin-top: 0; margin-bottom: 10px; font-weight: bold;">Join Types</h3>
# <ul style="font-size: 16px; line-height: 1.6; padding-left: 0; margin: 0; list-style-type: none; color: #264653;">
#     <li style="margin-bottom: 2px;"><strong style="color: #2a9d8f;"><code>how='outer'</code></strong> — Returns all rows from both DataFrames, filling missing values with NaN.</li>
#     <li style="margin-bottom: 2px;"><strong style="color: #2a9d8f;"><code>how='inner'</code></strong> — Returns only rows with matching keys in both DataFrames.</li>
#     <li style="margin-bottom: 2px;"><strong style="color: #2a9d8f;"><code>how='left'</code></strong> — Returns all rows from left DataFrame, with matching rows from right.</li>
#     <li style="margin-bottom: 0;"><strong style="color: #2a9d8f;"><code>how='right'</code></strong> — Returns all rows from right DataFrame, with matching rows from left.</li>
# </ul>
# </div>

# %%
#  Create DataFrame
import pandas as pd
data1 = [("Alice", 1),("Charlie", 2),("Bob", 3)]
columns1 = ["name1", "value1"]

left_Df = pd.DataFrame(data1, columns=columns1)
left_Df

data2 = [("Alice", 10), ("Bob", 20), ("David", 30)]
columns2 = ["name2", "value2"]
right_df = pd.DataFrame(data2, columns=columns2)
right_df
# Out:
#      name1  value1
# 0    Alice       1
# 1  Charlie       2
# 2      Bob       3

# %%
# pd.merge(leftDf,rightdf,left_on="col",right_on="ColName",how="left")

pd.merge(left_Df,right_df,left_on='name1',right_on='name2',how="outer")
# Out:
#    name2  value2
# 0  Alice      10
# 1    Bob      20
# 2  David      30

# %%
# Out:
#      name1  value1  name2  value2
# 0    Alice     1.0  Alice    10.0
# 1  Charlie     2.0    NaN     NaN
# 2      Bob     3.0    Bob    20.0
# 3      NaN     NaN  David    30.0

# %%
# merge()
# Outer join
# in merge method common_key is considered

# pd.merge(df1, df2, left_on='NameOfCol', right_on='NameOfCol', how='outer')

pd.merge(df1,df2,left_on='name1',right_on='name2',how='outer')

# %% [markdown]
# # <h2 style="color: #2a9d8f; font-family: 'Candara', sans-serif; font-weight: bold; text-align: left;margin:-60px 0 0 0; padding-bottom: 10px; border-bottom: 2px solid #264653;">Adding New Columns to a DataFrame </h2>
# })</code></p>
# </li>
#
# </ul>

# %% [markdown]
# <p style="color:#264653; font-family:Candara, sans-serif; font-size:17px; line-height:1; margin:0;">
# Adding new columns to a DataFrame can be done in several ways. Below are the most popular methods:
# </p>
#
# <ul style="font-family:Candara, sans-serif; fon6-size:17px; line-height:1; padding-left:15px; margin:0; list-style-type:none;">
#
# <li style="color:#2a9d8f; margin:0;">
# <b>Directly Adding a Column</b><br>
# <p style="margin:0 0 0 20px;">Description: You can directly add a new column by assigning values to a new column label.</p>
# <p style="margin:0 0 0 20px;">Syntax: <code>df['new_column_name'] = value</code></p>
# <p style="margin:0 0 0 20px;">Example: <code>df['NewColumn'] = [1, 2, 3, 4]</code></p>
# </li>
#
# <li style="color:#2a9d8f; margin:0;">
# <b>Adding a Column Based on Existing Column</b><br>
# <p style="margin:0 0 0 20px;">Description: Create a new column based on operations or transformations of existing columns.</p>
# <p style="margin:0 0 0 20px;">Syntax: <code>df['new_column'] = df['existing_column'] * factor</code></p>
# <p style="margin:0 0 0 20px;">Example: <code>df['DoubleAge'] = df['Age'] * 2</code></p>
# </li>
#
# <li style="color:#2a9d8f; margin:0;">
# <b>Use of Dictionary</b><br>
# <p style="margin:0 0 0 20px;">Description: Add a new column using a dictionary, where keys are index labels and values are column values.</p>
# <p style="margin:0 0 0 20px;">Syntax: <code>df['new_column'] = pd.Series(dictionary)</code></p>
# <p style="margin:0 0 0 20px;">Example: <code>df['City'] = pd.Series({0:'New York',1:'Los Angeles',2:'Chicago'})</code></p>
# </li>
#
# </ul>

# %%
# Read Excel

import pandas as pd
file_path = "D:/Old Projects/MLProjects/ZDatasets/DummyData/Data_Train1.csv"
df = pd.read_csv(file_path)

df['NewAge'] = df['Age'] + 2
df

# %%
# Create new column using dictionary
new_data = {"Ram"   :"B.Com",
            "Mohan" :"IAS",
            "Tina"  :"LLB",
            "Jeetu" :"B.Tech",
            "Meera" :"MBBS",
            "Rajesh" :"BHM",
            "Sanjay" : "llm",
            "Trishul" :"BAMS", 
            "Sameer" : "Forensic Science",
            "Amol" : "under Graduate",
            "Praveen" : "ias",
            "Sunita": "IPS"
}

new_data

# %%
df['Edu'] = df['First_name'].map(new_data)

# %%
df

# %%
df["NewAge"] = 23
df

# %%
df["NewAge"] = df['Age'] + 2
df

# %% [markdown]
# #
# <h2 style="color: #2a9d8f; font-family: 'Candara', sans-serif; font-weight: bold; text-align: left; margin:-60px 0 0 0; padding-bottom: 10px; border-bottom: 2px solid #264653;">
# Replacing / Updating Value
# </h2>>
#
#
# </ul>
# writing existing values.
# </p>
# </li>
#
# </ul>

# %% [markdown]
# <p style="color:#264653; font-family:Candara, sans-serif; font-si4e:17px; line-height:1.4; margin:0;">
# Replacing or updating values in a DataFrame is a common task in data cleaning and manipulation. You can achieve this using the following pandas methods:
# </p>
#
# <ul style="font-family:Candara, sans-serif; fon4-size:17px; line-height:1.4; padding-left:15px; margin:0; list-style-type:none;">
#
# <li style="color:#2a9d8f; margin-top:10px;">
# <b>.replace</b><br>
#
# <p style="margin:0 0 0 20px;">
# Example:
# </p>
# <p style="margin:0 0 0 40px;">
# <code>df.replace({'old_val': 'new_val'})</code> – Replaces <b>'old_val'</b> with <b>'new_val'</b> across the DataFrame.
# </p>
#
#
# <p style="margin:0 0 0 20px;">
# Description: The <code>replace</code> method allows you to replace specified values with another value in a DataFrame or Series.
# </p>
#
# <p style="margin:0 0 0 20px;">
# Syntax: <code>df.replace(to_replace=None, inplace=False,True)</code>
# </p>
# </li>
#
# <li style="color:#2a9d8f; margin-top:15px;">
# <b>.update</b><br>
#
# <p style="margin:0 0 0 20px;">
# Example:
# </p>
# <p style="margin:0 0 0 40px;">
# <code>df.update(df2)</code> – Updates <code>df</code> with non-NA values from <code>df2</code>.
# </p>
# <p style="margin:0 0 0 40px;">
# <code>df.update(df2, overwrite=False)</code> – Updates <code>df</code> without overwriting existing values.
# </p>
#
# <p style="margin:0 0 0 20px;">
# Description: The <code>update</code> method updates the DataFrame with non-NA values from another DataFrame.
# </p>
#
#
#
# </ul>
# writing existing values.
# </p>
# </li>
#
# </ul>

# %%
# Replace
# Update
'''Replacing Existing with new value'''

import pandas as pd
import numpy as np

df = pd.DataFrame({
    "Name": ["Ram", "Mohan", "Jeetu", "Ram"],
    "Score": [0, 85, 0, 90]
})

df

# %%
newListDict = { "Ram": "Rameshwar",
                 "Mohan": "Manmohan"}

df.replace(newListDict)

# %%
df['Name']

# %%
'''Replacing Existing with new value Method 02'''

new_data={0:"Ram",
          1:"Mohan",
          2:"Jeetendra",
          3:"Rakesh"}

df['Name'].update(new_data)
df

# %%
file_path = "D:\\Old Projects\\MLProjects\\ZDatasets\\DummyData\\file.xlsx"
df = pd.read_excel(file_path)

df

# %% [markdown]
# # <h2 style="color: #2a9d8f; font-family: 'Candara', sans-serif; font-weight: bold; text-align: left; margin:-60px 0 0 0;padding-bottom: 10px; border-bottom: 2px solid #264653;">Finding & Dropping Duplicates</h2>l>

# %% [markdown]
# <p style="color:#264653; font-family:Candara, sans-serif; font-si6e:17px; line-height:1; margin:0;">
# Identifying and removing duplicate values is crucial for data cleaning. Here’s how to do it using pandas:
# </p>
#
# <ul style="font-family:Candara, sans-serif; font-size:17px; line-height:1; padding-left:15px; margin:0; list-style-type:none;">
#
# <li style="color:#2a9d8f; margin:0;">
# <b>Identifying Duplicates</b><br>
# <p style="margin:0 0 0 20px;">Find duplicate rows with: <code>df[df.duplicated()]</code></p>
# </li>
#
# <li style="color:#2a9d8f; margin:0;">
# <b>Dropping Duplicates</b><br>
# <p style="margin:0 0 0 20px;">Remove duplicate rows with: <code>df.drop_duplicates(inplace=True)</code></p>
# </li>
#
# </ul>
# >
#     </li>
# </ol>

# %%
df

# %%
df.duplicated()

# %%
df[df.duplicated()]

# %%
df.drop_duplicates(inplace = True)
df

# %% [markdown]
# # <h2 style="color: #2a9d8f; font-family: 'Candara', sans-serif; font-weight: bold; text-align: left; margin:-60px 0 0 0;padding-bottom: 10px; border-bottom: 2px solid #264653;">Dropping Rows or Columns</h2>l>

# %% [markdown]
# <p style="color:#264653; font-family:Candara, sans-serif; font-size:17px; line-height:1; margin:0;">
# Dropping rows or columns can be essential for data cleaning. Here’s how to do it using pandas:
# </p>
#
# <ul style="font-family:Candara, sans-serif; font-size:17px; line-height:1; padding-left:15px; margin:0; list-style-type:none;">
#
# <li style="color:#2a9d8f; margin:0;">
# <b>Drop Rows</b><br>
# <p style="margin:0 0 0 20px;">Remove rows with: <code>df.drop(index, axis=0, inplace=True)</code></p>
# </li>
#
# <li style="color:#2a9d8f; margin:0;">
# <b>Drop Columns</b><br>
# <p style="margin:0 0 0 20px;">Remove columns with: <code>df.drop(columns, axis=1, inplace=True)</code></p>
# </li>
#
# </ul>
#
#     </li>
# </ol>

# %%
# Drop Columns
'''Now Drop the Date_of_Journey,Dep_Time,Arrival_Time '''

# 0 = row 
# 1 = Column  

NEWdF = df.drop(["First_name","Last_name"],axis=1)

NEWdF

# %%
# Drop Rows
newDf = df.drop([0,2,3],axis=0)
newDf

# %%
'''Drop rows whoes age is 52'''

indexNuber = df[df['Age']==52].index
indexNuber

# %%
df.drop(indexNuber,axis=0)

# %% [markdown]
# # <h2 style="color: #2a9d8f; font-family: 'Candara', sans-serif; font-weight: bold; text-align: left; margin:-60px 0 0 0;padding-bottom: 10px; border-bottom: 2px solid #264653;">Changing Column Names</h2>
# 2>
# l>
#     </li>
# </ol>

# %% [markdown]
# <p style="color:#264653; font-family:Candara, sans-serif; font-si5e:17px; line-height:1; margin:0;">
# Renaming columns in a DataFrame can help make the data more understandable. Here's how to change column names using pandas:
# </p>
#
# <ul style="font-family:Candara, sans-serif; font-size:17px; line-height:1; padding-left:15px; margin:0; list-style-type:none;">
#
# <li style="color:#2a9d8f; margin:0;">
# <b>Rename Columns</b><br>
# <p style="margin:0 0 0 20px;">Change column names with: <code>df.rename(columns={'old_name': 'new_name'}, inplace=True)</code></p>
# </li>
#
# <li style="color:#2a9d8f; margin:0;">
# <b>Set New Column Names</b><br>
# <p style="margin:0 0 0 20px;">Assign new column names with: <code>df.columns = ['new_name1', 'new_name2', ...]</code></p>
# </li>
#
# </ul>
#     </li>
# </ol>

# %%
df.columns

# %%
file_path = "D:/Old Projects/MLProjects/ZDatasets/DummyData/file.xlsx"
df = pd.read_excel(file_path)

df.columns

# %%
'''Change column names in Pandas DataFrame'''
'''Method 01'''

newColName = {'First_name':'Given_Name', 'Last_name':'SurName'}

df.rename(columns=newColName,inplace=True)
df

# %%
df.columns = ['abc_name', 'xyz_name', 'Age', 'City_afadfads', 'Airline', 'Date_of_Journey',
       'Dep_Time', 'Arrival_Time', 'Dept_Hour', 'Dept_Minute', 'Arrival_Hour',
       'Arrival_Minute', 'Full Name']
df

# %% [markdown]
# ## <h2 style="color: #2a9d8f; font-family: 'Candara', sans-serif; font-weight: bold; text-align: left;margin:-60px 0 0 0; padding-bottom: 10px; border-bottom: 2px solid #264653;">Iteration over DataFrame</h2>
# /ol>

# %% [markdown]
# <div style="
#     background-color: #f7faf9;
#     border: 1px solid #d2e6e3;
#     border-left: 6px solid #2a9d8f;
#     padding: 20px;
#     border-radius: 4px;
#     margin: 15px 0;
#     font-family: 'Candara', 'Segoe UI', sans-serif;
# ">
#     <p style="color: #264653; font-size: 18px; line-height: 1.6; margin-top: 0; margin-bottom: 15px;">
#         Iterating over a DataFrame can be done in several ways depending on your needs. Here are some common methods:
#     </p>
#
# <ul style="margin: 0; padding-left: 20px; list-style-type: square; color: #2a9d8f;">
#     <li>
#         <strong style="font-size: 16px;">Using <code>items()</code></strong>
#         <p style="color: #264653; font-size: 16px; margin: 4px 0 0 0; line-height: 1.5;">
#             Iterate over DataFrame columns as (column_name, Series) pairs with:
#             <code>for column_name, series in df.items():</code>
#         </p>
#     </li>
# </ul>
# </div>

# %%
for key, vlaues in df.items():
    print(key)
    print("---------")
    print(vlaues)

# %% [markdown]
# <h2 style="color: #2a9d8f; font-family: 'Candara', sans-serif; font-weight: bold; text-align: left; padding-bottom: 10px; border-bottom: 2px solid #264653;">Use of Map </h2>
# <ul>
#   <li><b>Using <code>map()</code></b>
#       <p>Map values of a Series using a function or dict with: <code>df['column'].map(func)</code> or <code>df['column'].map(dict)</code></p>
#    </l
#    </li>
#   </ul>

# %%
# map
import pandas as pd
file_path = "D:/Old Projects/MLProjects/ZDatasets/DummyData/Data_Train1.csv"

df = pd.read_csv(file_path)

df 

newDict = {"Ram":"R", "Mohan":"M","Tina":"T","Jeetu":"J","Meera":"Me"}

df

df['First_name'] = df['First_name'].map(newDict)
df

# %%
import pandas as pd
file_path = "D:/Old Projects/MLProjects/ZDatasets/DummyData/Data_Train1.csv"
df = pd.read_csv(file_path)

def newAirfareRoundedValue(x):
     return round(x+5)
    
df['NewAifare'] = df['Airfare'].map(newAirfareRoundedValue)
df

# %% [markdown]
# # <h2 style="color: #2a9d8f; font-family: 'Candara', sans-serif; font-weight: bold; text-align: left;margin:-60px 0 0 0; padding-bottom: 10px; border-bottom: 2px solid #264653;">Working with Index in Pandas</h2>
# l>
#   </p>
#     </li>
# </ol>

# %% [markdown]
# <p style="color:#264653;"><b>The index in a DataFrame is crucial for data alignment and access. Here are some common operations for working with indices:</b></p>
#
# 1. <span style="color:#2a9d8f;">**Set Index (set column as Index)**</span>
#    `df.set_index('column_name', inplace=True)`
#    Replace 'column_name' with the name of the column to be set as the index.
#
# 2. <span style="color:#2a9d8f;">**Reindex (Reindex rows or columns)**</span>
#    `df.reindex(new_index)` for rows
#    `df.reindex(columns=new_columns)` for columns.
#    Provide `new_index` or `new_columns` with the new index or column labels.
#
# 3. <span style="color:#2a9d8f;">**Reset Index (Reset the index to default)**</span>
#    `df.reset_index(drop=False, inplace=True)`
#    Use `drop=True` to remove the index column from the DataFrame.

# %%
# Set index
'''Make a column of dataframe as index with remove default index.'''
newDict = {'Date'           :['10/2/2011', '11/2/2011', '12/2/2011', '13/2/2011'],
            'Product'       :[' UMbreLla', '  maTtress', 'BaDmintoN ', 'Shuttle'],
            'Price'         :[1250, 1450, 1550, 400],
            'Discount'      :[10, 8, 15, 10]}

df1=pd.DataFrame(newDict)
df1

# %%
df1.set_index(["Date","Product","Price"],inplace=True)
df1

# %%
# rendex: this will change the sequence of the dataframe'

# import numpy and pandas module
import pandas as pd

newDict = {'Date':['10/2/2011', '11/2/2011', '12/2/2011', '13/2/2011'],
                   'Product':[' UMbreLla', '  maTtress', 'BaDmintoN ', 'Shuttle'],
                   'Updated_Price':[1250, 1450, 1550, 400],
                   'Discount':[10, 8, 15, 10]}

index=[11,12,13,14]
df1=pd.DataFrame(newDict,index=index)
df1

# %%
newIndex=[12,14,11,13]

df1.reindex(newIndex)

# %%
'''Reset the index and make default index as index.'''

newDict = {'Date':['10/2/2011', '11/2/2011', '12/2/2011', '13/2/2011'],
                   'Product':[' UMbreLla', '  maTtress', 'BaDmintoN ', 'Shuttle'],
                   'Updated_Price':[1250, 1450, 1550, 400],
                   'Discount':[10, 8, 15, 10]}

index=[11,12,13,14]

df1=pd.DataFrame(newDict,index=index)
df1

# %%
df1.reset_index(inplace=True,drop=True)
df1

# %% [markdown]
# # <h2 style="color: #2a9d8f; font-family: 'Candara', sans-serif; font-weight: bold; text-align: left;margin:-60px 0 0 0; padding-bottom: 10px; border-bottom: 2px solid #264653;">Sorting DataFrames in Pandas</h2>l>

# %% [markdown]
# <p style="color:#264653; font-family:Candara, sans-serif; font-size:17px; line-height:1; margin:0;">
# Sorting a DataFrame can help in organizing data based on index or column values. Here are some common methods for sorting:
# </p>
#
# <ul style="font-family:Candara, sans-serif; font-size:17px; line-height:1; padding-left:15px; margin:0; list-style-type:none;">
#
# <li style="color:#2a9d8f; margin:0;">
# <b>Sort by Index</b><br>
# <p style="margin:0 0 0 20px;">
# For rows: <code>df.sort_index(axis=0, ascending=True, inplace=True)</code><br>
# For columns: <code>df.sort_index(axis=1, ascending=True, inplace=True)</code><br>
# Set <code>ascending=False</code> for descending order.
# </p>
# </li>
#
# <li style="color:#2a9d8f; margin:0;">
# <b>Sort by Column Values</b><br>
# <p style="margin:0 0 0 20px;">
# <code>df.sort_values(by=['column1', 'column2'], ascending=[True, False], inplace=True)</code><br>
# Provide a list of columns and corresponding boolean values for ascending or descending order.
# </p>
# </li>
#
# </ul>
# </p>
#     </li>
# </ol>

# %%
import pandas as pd


initial_data = {'First_name' : ['Ram', 'Mohan', 'Tina', 'Jeetu', 'Meera'],
                'Last_name'  : ['Kumar', 'Sharma', 'Ali', 'Gandhi', 'Kumari'],
                'Age'        : [42, 52, 36, 21, 23],
                'City'       : ['Mumbai', 'Noida', 'Pune', 'Delhi', 'Bihar']}

df= pd.DataFrame(initial_data)

df

# %%
# sort_values(by=[NameOfColumn],ascending=True/False)

df.sort_values(by=['First_name'],ascending=False)

# %%
# Sort Index by Rows
df.sort_index(axis=0)

# %%
# Sort Index by Columns
df.sort_index(axis=0)
